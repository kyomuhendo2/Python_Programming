# %%
"""
Gaussian_Elimination_Method

Solve by G-E

#Number 1

"""

# %%
"""
Gaussian_Elimination_Method

Solve by G-E

# Number 4

0.003x + 59.14y = 59.17
5.291x + 6.13y = 46.78

"""
row1 = [0.003, 59.14, 59.17]
row2 = [5.291, -6.13, 46.78]

# calculating row 2 co-eeficient

row2_coefficient = row2[0] / row1[0]
print("row2_coefficient = ", row2_coefficient)
#rounded_row2_coefficient = round(row2_coefficient, 4)
#print("rounded_row2_coefficient = ", rounded_row2_coefficient)

# calculating row 2 col 1 value using the row 2 co-eeficient

operation_2_row2_col1 = row2[0] - (row2_coefficient * row1[0])
print("Row2_Col1: R2 = R2 - 1763.6667R1 =  = ", operation_2_row2_col1)
#operation_2_row2_col1 = row2[0] - (rounded_row2_coefficient * row1[0])
#rounded_operation_2_row2_col1 = round(operation_2_row2_col1, 4)
#print("Row2_Col1: R2 = -R2 + 1763.6667R1 = ", rounded_operation_2_row2_col1)

# calculating row 2 col 2 value using the row 2 co-eeficient
operation_2_row2_col2 = row2[1] - (row2_coefficient * row1[1])
print("Row2_Col2: R2 = R2 - 1763.6667R1 =  = ", operation_2_row2_col2)
#operation_2_row2_col2 = row2[1] - (rounded_row2_coefficient * row1[1])
#rounded_operation_2_row2_col2 = round(operation_2_row2_col2, 4)
#print("Row2_Col2: R2 = -R2 + 1763.6667R1 = ", rounded_operation_2_row2_col2)

# calculating row 2 col 3 value using the row 2 co-eeficient
operation_2_row2_col3 = row2[2] - (row2_coefficient * row1[2])
print("Row2_Col3: R2 = R2 - 1763.6667R1 =  = ", operation_2_row2_col3)
#operation_2_row2_col3 = row2[2] - (rounded_row2_coefficient * row1[2])
#rounded_operation_2_row2_col3 = round(operation_2_row2_col3, 4)
#print("Row2_Col3: R2 = -R2 + 1763.6667R1 = ", rounded_operation_2_row2_col3)

#finding the value of y

y = operation_2_row2_col3 / operation_2_row2_col2
#y = rounded_operation_2_row2_col3 / rounded_operation_2_row2_col2
round_y = round(y, 4)
print("y = ", round_y)

#Finding the value of x; row1_col1 = 0.003 * x

row1_col2 = 59.14 * round_y
round_row1_col2 = round(row1_col2, 4)
print("round_row1_col2 = ", round_row1_col2)

x = (row1[2] - (59.14 * round_y)) / row1[0]
print("x = ", x)
round_x = round(x, 4)
print("x = ", round_x)
# Out:
# row2_coefficient =  1763.6666666666667
# Row2_Col1: R2 = R2 - 1763.6667R1 =  =  0.0
# Row2_Col2: R2 = R2 - 1763.6667R1 =  =  -104309.37666666668
# Row2_Col3: R2 = R2 - 1763.6667R1 =  =  -104309.37666666668
# y =  1.0
# round_row1_col2 =  59.14
# x =  10.000000000000378
# x =  10.0

# %%
"""
Gaussian_Elimination_Method

Solve by G-E

# Number 5

Eqn 1: 1.780a + 3.008b - 4.880c = -7.704
Eqn 2: 4.632a  - 1.064b - 2.274c = -6.359
Eqn 3: -3.387a + 9.814b - 4.779c = 3.946

"""

A = [1.780, 3.008, 4.880, -7.704]
B = [4.632, 1.064, 2.274, -6.359]
C = [-3.387, 9.814, 4.779, 3.946]

# calculating row 2 co-eeficient
B_coefficient = B[0] / A[0]
print("B_coefficient = ", B_coefficient)
#rounded_B_coefficient = round(B_coefficient, 4)
#print("rounded_B_coefficient = ", rounded_B_coefficient)
print("-------------------------------------------------------------")

#Col 2 operation

# calculating row 2 col 1 value using the row 2 co-eeficient

#operation_2_B_col1 = row2[0] - (rounded_B_coefficient * A[0])
operation_2_B_col1 = B[0] - (B_coefficient * A[0])
#rounded_operation_2_B_col1 = round(operation_2_B_col1, 4)
#print("Row2_Col1: R2 = -R2 + 2.6022R1 = ", rounded_operation_2_B_col1)
print("B_Col1: R2 = -R2 + 2.6022R1 = ", operation_2_B_col1)
print("-------------------------------------------------------------")

# calculating row 2 col 2 value using the row 2 co-eeficient

operation_2_B_col2 = B[1] - (B_coefficient * A[1])
#rounded_operation_2_B_col1 = round(operation_2_B_col1, 4)
#print("Row2_Col1: R2 = -R2 + 2.6022R1 = ", rounded_operation_2_B_col1)
print("B_Col2: R2 = -R2 + 2.6022R1 = ", operation_2_B_col2)
print("-------------------------------------------------------------")

# calculating row 2 col 3 value using the row 2 co-eeficient

operation_2_B_col3 = B[2] - (B_coefficient * A[2])
#rounded_operation_2_B_col1 = round(operation_2_B_col1, 4)
#print("Row2_Col1: R2 = -R2 + 2.6022R1 = ", rounded_operation_2_B_col1)
print("B_Col3: R2 = -R2 + 2.6022R1 = ", operation_2_B_col3)
print("-------------------------------------------------------------")

# calculating row 2 col 4 value using the row 2 co-eeficient

operation_2_B_col4 = B[3] - (B_coefficient * A[3])
#rounded_operation_2_B_col1 = round(operation_2_B_col1, 4)
#print("Row2_Col1: R2 = -R2 + 2.6022R1 = ", rounded_operation_2_B_col1)
print("B_Col4: R2 = -R2 + 2.6022R1 = ", operation_2_B_col4)
print("-------------------------------------------------------------")
print("                                                                ")

#New values of the three equations

A1 = [1.780, 3.008, 4.880, -7.704]
B1 = [operation_2_B_col1, operation_2_B_col2,  operation_2_B_col3, operation_2_B_col4]
C1 = [-3.387, 9.814, 4.779, 3.946]

#print the values of B1
#print("B1 = ", B1)

#rounded_B1 = round(B1[1], 4)
#print("rounded_B1 = ",rounded_B1)

# calculating row 3 co-eeficient
C1_coefficient = C[0] / A[0]
print("C1_coefficient = ", C1_coefficient)
#rounded_C_coefficient = round(C_coefficient, 4)
#print("rounded_C_coefficient = ", rounded_C_coefficient)
print("-------------------------------------------------------------")

#C1 col 1
print("C1[0]", C1[0]);
print("C1[1]", C1[1]);
print("C1[2]", C1[2]);
print("C1[3]", C1[3]);

operation_2_C1_col1 = C1[0] - (C1_coefficient * A[0])
print("C1_Col1: R3 = R3 - 2.6022R1 = ", operation_2_C1_col1)
print("-------------------------------------------------------------")
print("                                                                ")

#C1 col 2
operation_2_C1_col2 = C1[1] - (C1_coefficient * A[1])
print("C1_Col1: R3 = R3 - 2.6022R1 = ", operation_2_C1_col2)
print("-------------------------------------------------------------")
print("                                                                ")

#C1 col 3
operation_2_C1_col3 = C1[2] - (C1_coefficient * A[2])
print("C1_Col1: R3 = R3 - 2.6022R1 = ", operation_2_C1_col3)
print("-------------------------------------------------------------")
print("                                                                ")

#C1 col 4
operation_2_C1_col4 = C1[3] - (C1_coefficient * A[3])
print("C1_Col1: R3 = R3 - 2.6022R1 = ", operation_2_C1_col4)
print("-------------------------------------------------------------")
print("                                                                ")

#New values of the three equations

A2 = [1.780, 3.008, 4.880, -7.704]
B2 = [operation_2_B_col1, operation_2_B_col2,  operation_2_B_col3, operation_2_B_col4]
C2 = [operation_2_C1_col1, operation_2_C1_col2, operation_2_C1_col3, operation_2_C1_col4]

print(C2)

# calculating row 3 second co-eeficient
C2_coefficient = C1[0] / B[0]
print("C1_coefficient = ", C2_coefficient)
#rounded_C_coefficient = round(C_coefficient, 4)
#print("rounded_C_coefficient = ", rounded_C_coefficient)
print("-------------------------------------------------------------")

#C1 col 1
print("C1[0]", C1[0]);
print("C1[1]", C1[1]);
print("C1[2]", C1[2]);
print("C1[3]", C1[3]);

operation_2_C1_col1 = C1[0] - (C1_coefficient * A[0])
print("C1_Col1: R3 = R3 - 2.6022R1 = ", operation_2_C1_col1)
print("-------------------------------------------------------------")
print("                                                                ")

#C1 col 2
operation_2_C1_col2 = C1[1] - (C1_coefficient * A[1])
print("C1_Col1: R3 = R3 - 2.6022R1 = ", operation_2_C1_col2)
print("-------------------------------------------------------------")
print("                                                                ")

#C1 col 3
operation_2_C1_col3 = C1[2] - (C1_coefficient * A[2])
print("C1_Col1: R3 = R3 - 2.6022R1 = ", operation_2_C1_col3)
print("-------------------------------------------------------------")
print("                                                                ")

#C1 col 4
operation_2_C1_col4 = C1[3] - (C1_coefficient * A[3])
print("C1_Col1: R3 = R3 - 2.6022R1 = ", operation_2_C1_col4)
print("-------------------------------------------------------------")
print("                                                                ")

#New values of the three equations
# Out:
# B_coefficient =  2.602247191011236
# -------------------------------------------------------------
# B_Col1: R2 = -R2 + 2.6022R1 =  0.0
# -------------------------------------------------------------
# B_Col2: R2 = -R2 + 2.6022R1 =  -6.763559550561798
# -------------------------------------------------------------
# B_Col3: R2 = -R2 + 2.6022R1 =  -10.42496629213483
# -------------------------------------------------------------
# B_Col4: R2 = -R2 + 2.6022R1 =  13.688712359550562
# -------------------------------------------------------------
#
# C1_coefficient =  -1.902808988764045
# -------------------------------------------------------------
# C1[0] -3.387
# C1[1] 9.814
# C1[2] 4.779
# C1[3] 3.946
# C1_Col1: R3 = R3 - 2.6022R1 =  0.0
# -------------------------------------------------------------
#
# C1_Col1: R3 = R3 - 2.6022R1 =  15.537649438202248
# -------------------------------------------------------------
#
# C1_Col1: R3 = R3 - 2.6022R1 =  14.06470786516854
# ...
